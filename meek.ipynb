# %%
from utils import *

# %%
n = 4
G1 = random_dag(n,0.3)
B = random_confounding(n,2)
print (G1.edges,B)
# Out:
# [(1, 3), (3, 2)] [(3, 4), (2, 3)]

# %%
find_equivalence_class_meek(G1.edges(),B,n)
# Out:
# [{(1, 3), (3, 2)}, {(1, 3), (3, 2), (4, 3)}]

# %%
find_equivalent_graphs_exhaustive(G1.edges(),B,n)
# Out:
# Confounding:
# [(3, 4), (2, 3)]
# ---Edges---
# [(1, 3), (3, 2)]
# [(1, 3), (3, 2), (4, 3)]
